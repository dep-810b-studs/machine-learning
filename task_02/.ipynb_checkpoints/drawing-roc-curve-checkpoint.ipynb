# %%
import sklearn.metrics as metrics
import matplotlib.pyplot as plt

y_test = [1, 1, 1, -1, 1, -1, -1, 1]
preds = [0.95, 0.9, 0.8, 0.6, 0.3, 0.25, 0.2, 0.1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import scikitplot as skplt
import numpy as np

y_test = np.array([1, 1, 1, -1, 1, -1, -1, 1])
preds = np.array([0.95, 0.9, 0.8, 0.6, 0.3, 0.25, 0.2, 0.1])

skplt.metrics.plot_roc(y_test,preds)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-5165a158e15b> in <module>
#       5 preds = np.array([0.95, 0.9, 0.8, 0.6, 0.3, 0.25, 0.2, 0.1])
#       6
# ----> 7 skplt.metrics.plot_roc(y_test,preds)
#       8 plt.show()
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\scikitplot\metrics.py in plot_roc(y_true, y_probas, title, plot_micro, plot_macro, classes_to_plot, ax, figsize, cmap, title_fontsize, text_fontsize)
#     412     indices_to_plot = np.in1d(classes, classes_to_plot)
#     413     for i, to_plot in enumerate(indices_to_plot):
# --> 414         fpr_dict[i], tpr_dict[i], _ = roc_curve(y_true, probas[:, i],
#     415                                                 pos_label=classes[i])
#     416         if to_plot:
#
# IndexError: too many indices for array
